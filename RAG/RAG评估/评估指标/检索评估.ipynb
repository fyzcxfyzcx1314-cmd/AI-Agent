# %% [markdown]
# # 上下文相关性（ Context Relevancy）

# %% [markdown]
# 检索出的上下文与输入问题之间的相关性。一般使用不多

# %% [markdown]
# # 上下文精度（ Context Precision）

# %% [markdown]
# 说法一：检索出的上下文（context）中与参考答案（reference_answer）相关的部分在上下文（context）中是否出现在最前面的位置，这种较为常用。

# %% [markdown]
# 说法二：检索到的上下文（context）中 相关信息的比例，可以理解为
#
#
# Context Precision=上下文中与问题相关的信息数量/上下文总信息数量

# %% [markdown]
# # 上下文召回率（ Context Recall）

# %% [markdown]
# 衡量检索到的上下文中是否包含回答问题所需的全部关键信息，或者说检索到的上下文（context）与参考答案（ reference_answer）之间的一致程度，有时也称为命中率（ hit_rate）
#
# Context Recall=上下文中包含的关键信息数量/参考答案中关键信息数量
